# %% [markdown]
# <a href="https://colab.research.google.com/github/ramirezluna-david/mly1101-machine-learning-portafolio/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Script de diagnóstico del entorno MLY1101
import sys
import numpy as np
import pandas as pd
import matplotlib
print("=== DIAGNÓSTICO DEL ENTORNO DE DESARROLLO ===")
print(f"Versión de Python instalada: {sys.version}")
print(f"Versión de NumPy: {np.__version__}")
print(f"Versión de Pandas: {pd.__version__}")
print(f"Versión de Matplotlib: {matplotlib.__version__}")
print("============================================")
print("¡Entorno verificado con éxito para análisis exploratorio!")
# Out:
# === DIAGNÓSTICO DEL ENTORNO DE DESARROLLO ===
# Versión de Python instalada: 3.13.15 (main, Aug  6 2026, 11:06:23) [GCC 11.4.0]
# Versión de NumPy: 2.1.3
# Versión de Pandas: 2.2.3
# Versión de Matplotlib: 3.10.0
# ============================================
# ¡Entorno verificado con éxito para análisis exploratorio!
